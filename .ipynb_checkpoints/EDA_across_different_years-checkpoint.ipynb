# %% [markdown]
# # Aim
#
# The aim of this code is to:
#
# 1. Perform some EDA, and inspect/go over the data
# 2. Explore a section of the data, see if any correlations exist
#
# I am looking at Section B which talks about using the internet to find information. Replacing missing data with NaN

# %%
#import the relavant packages
import datetime
import json
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import collections
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
# Read the data file and take a look at the data
local_folder = '.'
df = pd.read_sas(os.path.join(local_folder, 'hints5_cycle3_public.sas7bdat'),encoding='mac_roman')
df['Year'] = '2019'
#display all columns and the first couple of rows
pd.set_option('display.max_columns', None)
df.head(15);

# %%
#convert missing data with NaN for EDA
df['AgeGrpB'].replace([-9.0,-4.0], np.nan, inplace = True)
df['Age'].replace([-9.0,-4.0], np.nan, inplace = True)
df['SeekHealthInfo'].replace(-9.0, np.nan, inplace = True)
df['UseInternet'].replace(-9.0, np.nan, inplace = True)
df['Electronic_SelfHealthInfo'].replace(-9.0, np.nan, inplace = True)
df['Electronic_BuyMedicine'].replace(-9.0, np.nan, inplace = True)
df['Electronic_TalkDoctor'].replace(-9.0, np.nan, inplace = True)
df['Electronic_TrackedHealthCosts'].replace(-9.0, np.nan, inplace = True)
df['Electronic_MadeAppts'].replace(-9.0, np.nan, inplace = True)
df['TabletHealthWellnessApps'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)
df['HaveDevice_SmartPh'].replace([-9.0,-7.0], np.nan, inplace = True)
df['Tablet_AchieveGoal'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)
df['Tablet_MakeDecision'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)

# %% [markdown]
# Plot a correlation table

# %%
correlation =df[['UseInternet','Electronic_SelfHealthInfo','TabletHealthWellnessApps','Tablet_AchieveGoal',\
                'Tablet_MakeDecision','Electronic_TalkDoctor', \
   'Electronic_TrackedHealthCosts']].corr()
sns.heatmap(correlation, annot=True, cmap = 'Blues')
plt.show()

# %% [markdown]
# Not sure know to interpret this data, nor if this is a useful EDA for categorical data

# %% [markdown]
# ***Next*** we try pivot tables

# %%
#label the different age groups
df['AgeGrpB'].replace({1: '18-34', 2:'35-49', 3:'50-64', 4:'65-74',5:'75+'},inplace = True)
df['TabletHealthWellnessApps'].replace({1: 'Has App', 2:'No App', 3:"Don't know"},inplace = True)

# %%
table = pd.pivot_table(data=df, index='AgeGrpB', columns=['TabletHealthWellnessApps'],values='Tablet_AchieveGoal')
print(table)
# Out:
# TabletHealthWellnessApps  Don't know   Has App    No App
# AgeGrpB
# 18-34                       1.642857  1.185185  1.738462
# 35-49                       1.772727  1.231561  1.839506
# 50-64                       1.845070  1.337017  1.862776
# 65-74                       1.818182  1.492424  1.929515
# 75+                         1.983607  1.613139  1.949772

# %%
sns.heatmap(table, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()

# %% [markdown]
# a value closer to 1 means that the group are more likely to use the devices (tablet/smartphone) for health related goals, 2 means the opposite. So the plot shows that the 18-35 age group are most like to use their devices for health

# %% [markdown]
# # Loading Data from different years

# %% [markdown]
# In this section I am trying to get a plot of internet usage over time

# %%
# Read the data file and take a look at the data
local_folder = '.'
df2 = pd.read_sas(os.path.join(local_folder, 'hints5_cycle2_public.sas7bdat'),encoding='mac_roman')

#display all columns and the first couple of rows
pd.set_option('display.max_columns', None)
df2.head(15)

df2['Year'] = '2018'

# %%
# Read the data file and take a look at the data
local_folder = '.'
df3 = pd.read_sas(os.path.join(local_folder, 'hints5_cycle1_public.sas7bdat'),encoding='mac_roman')

#display all columns and the first couple of rows
pd.set_option('display.max_columns', None)
df3.head(15)

df3['Year'] = '2017'

# %%
# Read the data file and take a look at the data
local_folder = '.'
df4 = pd.read_sas(os.path.join(local_folder, 'hints4cycle2_07312020_public.sas7bdat'),encoding='mac_roman')

#display all columns and the first couple of rows
pd.set_option('display.max_columns', None)
df4.head(15)

df4['Year'] = '2013'

# %%
# Read the data file and take a look at the data
local_folder = '.'
df5 = pd.read_sas(os.path.join(local_folder, 'hints4cycle1_07312020_public.sas7bdat'),encoding='mac_roman')

#display all columns and the first couple of rows
pd.set_option('display.max_columns', None)
df5.head(15)

df5['Year'] = '2011'

# %%
df['UseInternet'].replace({1: 'Yes', 2:'No'},inplace = True)
df2['UseInternet'].replace({1: 'Yes', 2:'No'},inplace = True)
df3['UseInternet'].replace({1: 'Yes', 2:'No'},inplace = True)
df4['UseInternet'].replace({1: 'Yes', 2:'No'},inplace = True)
df5['UseInternet'].replace({1: 'Yes', 2:'No'},inplace = True)

# %%
#convert missing data with NaN for EDA
df2['AgeGrpB'].replace([-9.0,-4.0], np.nan, inplace = True)
df2['Age'].replace([-9.0,-4.0], np.nan, inplace = True)
df2['SeekHealthInfo'].replace(-9.0, np.nan, inplace = True)
df2['UseInternet'].replace(-9.0, np.nan, inplace = True)
df2['Electronic_SelfHealthInfo'].replace(-9.0, np.nan, inplace = True)
df2['Electronic_BuyMedicine'].replace(-9.0, np.nan, inplace = True)
df2['Electronic_TalkDoctor'].replace(-9.0, np.nan, inplace = True)
df2['Electronic_TrackedHealthCosts'].replace(-9.0, np.nan, inplace = True)
#df2['Electronic_MadeAppts'].replace(-9.0, np.nan, inplace = True)
df2['TabletHealthWellnessApps'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)
df2['HaveDevice_SmartPh'].replace([-9.0,-7.0], np.nan, inplace = True)
df2['Tablet_AchieveGoal'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)
df2['Tablet_MakeDecision'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)

df3['AgeGrpB'].replace([-9.0,-4.0], np.nan, inplace = True)
df3['Age'].replace([-9.0,-4.0], np.nan, inplace = True)
df3['SeekHealthInfo'].replace(-9.0, np.nan, inplace = True)
df3['UseInternet'].replace(-9.0, np.nan, inplace = True)
df3['Electronic_SelfHealthInfo'].replace(-9.0, np.nan, inplace = True)
df3['Electronic_BuyMedicine'].replace(-9.0, np.nan, inplace = True)
df3['Electronic_TalkDoctor'].replace(-9.0, np.nan, inplace = True)
df3['Electronic_TrackedHealthCosts'].replace(-9.0, np.nan, inplace = True)
#df2['Electronic_MadeAppts'].replace(-9.0, np.nan, inplace = True)
df3['TabletHealthWellnessApps'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)
df3['HaveDevice_SmartPh'].replace([-9.0,-7.0], np.nan, inplace = True)
df3['Tablet_AchieveGoal'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)
df3['Tablet_MakeDecision'].replace([-9.0,-7.0,-6.0,-5.0,-2.0,-1.0], np.nan, inplace = True)

df4['AgeGrpB'].replace([-9.0,-4.0], np.nan, inplace = True)
df4['Age'].replace([-9.0,-4.0], np.nan, inplace = True)
df4['SeekHealthInfo'].replace(-9.0, np.nan, inplace = True)
df4['UseInternet'].replace(-9.0, np.nan, inplace = True)


df5['AgeGrpB'].replace([-9.0,-4.0], np.nan, inplace = True)
df5['Age'].replace([-9.0,-4.0], np.nan, inplace = True)
df5['SeekHealthInfo'].replace(-9.0, np.nan, inplace = True)
df5['UseInternet'].replace(-9.0, np.nan, inplace = True)

# %%
df_sub = df[["Age", "UseInternet","Year"]]
#df2_sub = df2[["Age", "UseInternet","Year"]]
df3_sub = df3[["Age", "UseInternet","Year"]]
df4_sub = df4[["Age", "UseInternet","Year"]]
df5_sub = df5[["Age", "UseInternet","Year"]]

combined = pd.concat([df_sub,df3_sub,df4_sub,df5_sub], ignore_index=True)

# %%
combined
# Out:
#         Age UseInternet  Year
# 0      71.0          No  2019
# 1      47.0         Yes  2019
# 2       NaN         Yes  2019
# 3      65.0         Yes  2019
# 4      45.0         Yes  2019
# ...     ...         ...   ...
# 16307  62.0         Yes  2011
# 16308  66.0          No  2011
# 16309  27.0         Yes  2011
# 16310  47.0         Yes  2011
# 16311  48.0         Yes  2011
#
# [16312 rows x 3 columns]

# %%
sns.catplot(x="Age", y="UseInternet", row="Year",
                kind="box", orient="h", height=1.5, aspect=5,
                data=combined)

# %%
sns.catplot(x="Age", y="UseInternet", kind="box", data=df2);
sns.catplot(x="Age", y="UseInternet", kind="box", data=df);
